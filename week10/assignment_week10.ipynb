# %% [markdown]
# <a href="https://colab.research.google.com/github/perrymason-droid/ores5160-2026/blob/main/week10/assignment_week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Count Vowels
#
# Write a function `count_vowels(s)` that takes a string and returns the number of vowels in it (`a`, `e`, `i`, `o`, `u` — both upper and lower case).
#
# ```python
# >>> count_vowels("hello")
# 2
# >>> count_vowels("HEllO World")
# 3

# %%
### BEGIN SOLUTION
def count_vowels(s):
    """
    Return the number of vowels (a, e, i, o, u) in a string.

    >>> count_vowels("hello")
    2
    >>> count_vowels("HEllO World")
    3
    """
    vowels = "aeiouAEIOU"
    return sum(1 for ch in s if ch in vowels)
### END SOLUTION

# %%
assert count_vowels("hello") == 2
assert count_vowels("HELLO") == 2
assert count_vowels("xyz") == 0

# %%
import doctest
doctest.run_docstring_examples(count_vowels, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     count_vowels("hello")
# Expecting:
#     2
# ok
# Trying:
#     count_vowels("HEllO World")
# Expecting:
#     3
# ok

# %% [markdown]
# 2 BMI Calculator
#
# Write a function bmi(weight_kg, height_m) that returns the Body Mass Index (BMI) using the formula:
#
# $
# BMI = \frac{\text{weight (kg)}}{(\text{height (m)})^2}
# $
#
# Include doctests for values like:
# 	•	weight_kg=70, height_m=1.75 → 22.86 (rounded to two decimals)

# %%
### BEGIN SOLUTION
def bmi(weight_kg, height_m):
    """
    Calculate BMI using weight (kg) / height(m)^2.

    >>> round(bmi(70, 1.75), 2)
    22.86
    >>> round(bmi(50, 1.6), 2)
    19.53
    """
    return weight_kg / (height_m ** 2)
### END SOLUTION

# %%
assert round(bmi(70, 1.75), 2) == 22.86
assert round(bmi(50, 1.6), 2) == 19.53

# %%
import doctest
doctest.run_docstring_examples(bmi, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     round(bmi(70, 1.75), 2)
# Expecting:
#     22.86
# ok
# Trying:
#     round(bmi(50, 1.6), 2)
# Expecting:
#     19.53
# ok

# %% [markdown]
# 3 Filter Short Words
#
# Create a function filter_short(words, max_len) that returns a list of only those words whose length is less than or equal to max_len.
# ```python
# >>> filter_short(['hi', 'hello', 'no', 'yes'], 2)
# ['hi', 'no']

# %%
### BEGIN SOLUTION
def filter_short(words, max_len):
    """
    Return words whose length is <= max_len.

    >>> filter_short(['hi', 'hello', 'no', 'yes'], 2)
    ['hi', 'no']
    """
    return [w for w in words if len(w) <= max_len]
### END SOLUTION

# %%
assert filter_short(['hi', 'hello', 'no', 'yes'], 2) == ['hi', 'no']
assert filter_short(['apple', 'banana', 'pear'], 4) == ['pear']

# %%
import doctest
doctest.run_docstring_examples(filter_short, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     filter_short(['hi', 'hello', 'no', 'yes'], 2)
# Expecting:
#     ['hi', 'no']
# ok
